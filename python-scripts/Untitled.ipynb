# %%
from scipy.io import loadmat

# %%
data = loadmat("C:/Users/fredi/Box/JAGLAB/Students/Grads\FRM/research-projects/emg-fatigue/data/dynamic-80bpm-50")

# %%
print(data)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Tue Sep  6 18:17:23 2022', '__version__': '1.0', '__globals__': [], 'raw_data': array([[-2.5       , -2.5       , -2.5       , ..., -0.02929688,
#         -0.02929688, -0.02929688]])}

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data['raw_data'])
# Out:
# ...
#  ...]

# %%
import numpy as np

# %%
np.size(data['raw_data'])
# Out:
# 138923

# %%
type(data['raw_data'])
# Out:
# numpy.ndarray

# %%
data = data['raw_data']

# %%
type
